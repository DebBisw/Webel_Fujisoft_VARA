# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-c0b51fce-3d61-4e84-8ed1-af98f3fd849c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0b51fce-3d61-4e84-8ed1-af98f3fd849c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Here I am using a **Dataset** from **Kaggle** on sales to  predict future value of sales using ***Linear Regression***

# %%
import pandas as pd
df=pd.DataFrame(pd.read_csv('advertising.csv'))

# %% [markdown]
# **ASSIGNMENT 2 -LINEAR REGRESSION**

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df.info()
#summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.describe()
#statistical Summary
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 4)

# %%
#checking for null values
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %% [markdown]
# Hence no Null Values

# %%
df.head(30)
# Out:
#        TV  Radio  Newspaper  Sales
# 0   230.1   37.8       69.2   22.1
# 1    44.5   39.3       45.1   10.4
# 2    17.2   45.9       69.3   12.0
# 3   151.5   41.3       58.5   16.5
# 4   180.8   10.8       58.4   17.9
# 5     8.7   48.9       75.0    7.2
# 6    57.5   32.8       23.5   11.8
# 7   120.2   19.6       11.6   13.2
# 8     8.6    2.1        1.0    4.8
# 9   199.8    2.6       21.2   15.6
# 10   66.1    5.8       24.2   12.6
# 11  214.7   24.0        4.0   17.4
# 12   23.8   35.1       65.9    9.2
# 13   97.5    7.6        7.2   13.7
# 14  204.1   32.9       46.0   19.0
# 15  195.4   47.7       52.9   22.4
# 16   67.8   36.6      114.0   12.5
# 17  281.4   39.6       55.8   24.4
# 18   69.2   20.5       18.3   11.3
# 19  147.3   23.9       19.1   14.6
# 20  218.4   27.7       53.4   18.0
# 21  237.4    5.1       23.5   17.5
# 22   13.2   15.9       49.6    5.6
# 23  228.3   16.9       26.2   20.5
# 24   62.3   12.6       18.3    9.7
# 25  262.9    3.5       19.5   17.0
# ...

# %% [markdown]
# Importing all the reqquired packages

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
# Features and target variable
X = df[['TV', 'Radio', 'Newspaper']]
y = df['Sales']
# Spliting the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
# Create a linear regression model
model = LinearRegression()

# Fit the model on the training data
model.fit(X_train, y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %% [markdown]
# Here are the values of the MSE and R-squared

# %%
print(f'Mean Squared Error: {mse:.2f}')
print(f'R-squared: {r2:.2f}')
print(f'Mean Absolute Error: {mae:.2f}')
# Out:
# Mean Squared Error: 2.40
# R-squared: 0.91
# Mean Absolute Error: 1.12

# %% [markdown]
# The ***MSE of 2.40*** suggests that, on average, the squared differences between the actual and predicted sales values are lower compared to the previous model (MSE of 5.51). This indicates that the model's predictions are closer to the actual sales values.
#
# An*** R² of 0.91*** is quite high, suggesting that the model fits the data well.
#
# ***MAE of 1.12*** Indicates that the average absolute difference between the predicted and actual sales values is 1.12. This means that, on average, the predictions are quite close to the true values, which is a good indication of the model's accuracy.

# %%
# Visualizing the results
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, color='blue')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--', lw=2)
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Sales')
plt.show()

# %% [markdown]
# **ASSIGNMENT 1- Basic Classification with Random Forest**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
# Loading the Iris dataset
iris = load_iris()
data = pd.DataFrame(data=iris.data, columns=iris.feature_names)
data['target'] = iris.target

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import IsolationForest
#Splitting the dataset into training and testing sets
X = data.drop('target', axis=1)
y = data['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=40)

# %%
#Train Random Forest Classifier

clf=RandomForestClassifier(n_estimators=100,random_state=42)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # New Section

# %%
#Making predictions

y_pred=clf.predict(X_test)

#Calculating Accuracy
accuracy=accuracy_score(y_test,y_pred)
print(f"Accuracy:{accuracy:.1f}")

#Plotting feature importance
feature_importance=pd.Series(clf.feature_importances_,index=X.columns)
feature_importance.sort_values(ascending=True).plot(kind='bar')
# Out:
# Accuracy:1.0
# <Axes: >

# %% [markdown]
# Perfect Predictions An accuracy of 1.0 implies perfect predictions, meaning the predicted values exactly match the actual values.

# %% [markdown]
# **K-Means Clusttering-ASSIGNMENT 3**
#
# IRIS FLOWER CLASSIFICATION
#
# The data set consists samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor)

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3ba1d430-88bb-41c1-8a6b-d7697268235a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ba1d430-88bb-41c1-8a6b-d7697268235a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2=pd.DataFrame(pd.read_csv('IRIS.csv'))

# %% [markdown]
# Basic Understanding of Dataset

# %%
df2.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df2['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# Map species to numerical values
df2['species'] = df2['species'].map({
    'Iris-setosa': 0,
    'Iris-versicolor': 1,
    'Iris-virginica': 2
})

# %%
df2.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df2.head(150)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  cluster
# 0             5.1          3.5           1.4          0.2        0        1
# 1             4.9          3.0           1.4          0.2        0        1
# 2             4.7          3.2           1.3          0.2        0        1
# 3             4.6          3.1           1.5          0.2        0        1
# 4             5.0          3.6           1.4          0.2        0        1
# ..            ...          ...           ...          ...      ...      ...
# 145           6.7          3.0           5.2          2.3        2        0
# 146           6.3          2.5           5.0          1.9        2        2
# 147           6.5          3.0           5.2          2.0        2        0
# 148           6.2          3.4           5.4          2.3        2        0
# 149           5.9          3.0           5.1          1.8        2        2
#
# [150 rows x 6 columns]

# %% [markdown]
# Importing reqquired packages

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Drop the 'species' column as it is not needed for clustering
X = df2.drop(columns=['species'])

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply K-means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# Add cluster labels to the original DataFrame
df2['cluster'] = clusters
print(df2)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  cluster
# 0             5.1          3.5           1.4          0.2        0        1
# 1             4.9          3.0           1.4          0.2        0        1
# 2             4.7          3.2           1.3          0.2        0        1
# 3             4.6          3.1           1.5          0.2        0        1
# 4             5.0          3.6           1.4          0.2        0        1
# ..            ...          ...           ...          ...      ...      ...
# 145           6.7          3.0           5.2          2.3        2        0
# 146           6.3          2.5           5.0          1.9        2        2
# 147           6.5          3.0           5.2          2.0        2        0
# 148           6.2          3.4           5.4          2.3        2        0
# 149           5.9          3.0           5.1          1.8        2        2
#
# [150 rows x 6 columns]
# ...

# %% [markdown]
# **Iris-setosa: 0,**
# **Iris-versicolor: 1,**
# **Iris-virginica: 2**

# %%
# Plotting clusters using sepal length and sepal width
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df2, x='sepal_length', y='sepal_width', hue='cluster', palette='viridis')
plt.title('Clusters of Iris Species')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend(title='Cluster')
plt.show()

# %%
# Plotting clusters using petal length and petal width
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df2, x='petal_length', y='petal_width', hue='cluster', palette='viridis')
plt.title('Clusters of Iris Species')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend(title='Cluster')
plt.show()
